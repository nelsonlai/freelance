# %% [markdown]
# # Session 2: Reading Excel Files - Interactive Tutorial
#
# Welcome to Session 2! This interactive notebook will teach you comprehensive techniques for reading Excel files using Python.
#
# ## 📋 Learning Objectives
#
# By the end of this session, you will be able to:
# - Read single and multiple sheets
# - Handle different data types
# - Read specific ranges
# - Work with headers and indices
# - Use both pandas and openpyxl
#
# ## 🔧 Setup
#
# First, let's import the necessary libraries:
#
# ```python
# import pandas as pd
# import numpy as np
# from openpyxl import load_workbook
# from pathlib import Path
#
# print("Libraries imported successfully!")
# print(f"Pandas version: {pd.__version__}")
# ```
#
# ## Part 1: Basic Reading
#
# Let's create and read a simple Excel file:
