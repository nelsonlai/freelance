# %% [markdown]
# # Session 1: Setup and Basics - Python Excel Libraries
#
# Welcome to the first session! This interactive notebook will guide you through the fundamentals of working with Excel files in Python.
#
# ## 📋 Learning Objectives
#
# - Understand Excel file formats
# - Set up Python Excel libraries
# - Read and write Excel files with pandas
# - Work with DataFrames
# - Use openpyxl for advanced Excel operations
